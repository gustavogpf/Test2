# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavogpf/Test2/blob/master/Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass
import os

user = 'gustavogpf'
password = getpass('password')
os.environ['auth'] = user + ':' + password

# !git clone https://$auth@github.com/gustavogpf/test.git
# Out:
# password··········
# Cloning into 'test'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# %run /content/test/Test.ipynb
